# %% [markdown]
# # Reading from CSV file

# %%
# %python
df_customer = (spark.read.option("header", True)
  .option("inferSchema", True)
  .csv("/Volumes/data_lakehouse_project/bronze/source_system/source_crm/cust_info.csv"))
display(df)

# %% [markdown]
# # Writing in to The Bronze layer

# %%
# %python
df_customer.write.mode("overwrite").saveAsTable("data_lakehouse_project.bronze.raw_crm_dim_customer")

# %%
# %sql
SELECT *
FROM  data_lakehouse_project.bronze.raw_crm_dim_customer
